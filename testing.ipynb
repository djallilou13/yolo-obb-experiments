# %% [markdown]
# # Models Testing on Real Data
#
# This section evaluates the fine-tuned models on the held-out test set.

# %% [markdown]
# ## 1. Environment Setup

# %%
import os
import random
import shutil
import numpy as np
from pathlib import Path
from tqdm import tqdm
import yaml
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/jovyan/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## 2. Configuration & Utilities

# %%
# Setup Test Data
TEST_DATASET_PATH = Path("last-test")
IMG_EXTS = [".jpg", ".jpeg", ".png"]
WANDB_PROJECT = "YOUR_WANDB_PROJECT"
WANDB_ENTITY = "YOUR_WANDB_ENTITY" 

def create_test_yaml(test_path, run_name):
    """
    Creates a YAML file for the test dataset.
    """
    images_dir = test_path / "images"
    
    # Scan all valid image files
    test_images = []
    for ext in IMG_EXTS:
        test_images.extend(images_dir.rglob(f"*{ext}"))
        
    test_images = sorted(list(set(test_images)))
    print(f"[{run_name}] Total Test Images: {len(test_images)}")
    
    # Create txt path
    test_txt_path = Path(f"{run_name}_test.txt")
    
    with open(test_txt_path, 'w') as f:
        f.write('\n'.join([str(p.resolve()) for p in test_images]))
        
    # Create YAML
    yaml_content = f"""
path: {Path.cwd()}
train: {test_txt_path.resolve()} # Not used for validation but required
val: {test_txt_path.resolve()}  # Used for validation
test: {test_txt_path.resolve()} # Used for prediction/testing

nc: 1
names: ['object']
"""
    yaml_path = Path(f"{run_name}_test_dataset.yaml")
    with open(yaml_path, 'w') as f:
        f.write(yaml_content)
        
    return yaml_path

# %% [markdown]
# ## 3. Evaluation Loop

# %%
# Run Evaluation on All Models
# Paths are relative to the notebook location (runs/obb/...)
models_to_test = [
    "YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_5pct.pt",
    "YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_10pct.pt",
    "YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_20pct.pt",
    "YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_30pct.pt",
    "YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_40pct.pt",
    "YOLO_OBB_FineTuning_Results/yolo_obb_ft_5pct.pt",
    "YOLO_OBB_FineTuning_Results/yolo_obb_ft_10pct.pt",
    "YOLO_OBB_FineTuning_Results/yolo_obb_ft_20pct.pt",
    "YOLO_OBB_FineTuning_Results/yolo_obb_ft_30pct.pt",
    "YOLO_OBB_FineTuning_Results/yolo_obb_ft_40pct.pt",
    "YOLO_OBB_FineTuning_Results/yolo_obb_ft_50pct.pt",
    "YOLO_OBB_FineTuning_Results/yolo_obb_scratch_alpha_baseline_40.pt",
    "YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_Real_Data_only.pt",
    "YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_E1_Synthesized_only.pt"
    
]
results_summary = {}
test_yaml = create_test_yaml(TEST_DATASET_PATH, "final_test")

for model_name in models_to_test:
    model_path = Path(model_name)
    
    if not model_path.exists():
        print(f"Model {model_name} not found at {model_path.resolve()}. Skipping.")
        continue
        
    print(f"\nEvaluating {model_name}...")
    try:
        model = YOLO(model_path)
        # Extract valid run name for wandb
        run_name = model_path.parent.parent.name # e.g. yolo_obb_ft_5pct
        
        metrics = model.val(data=str(test_yaml), split='test', project=WANDB_PROJECT, name=f"test_{run_name}")
        
        results_summary[model_name] = {
            "map50": metrics.box.map50,
            "map50-95": metrics.box.map,
            "precision": metrics.box.mp,  # mean precision
            "recall": metrics.box.mr      # mean recall
        }
        print(f"Result for {model_name}:")
        print(f"  mAP50={metrics.box.map50:.4f}, mAP50-95={metrics.box.map:.4f}")
        print(f"  Precision={metrics.box.mp:.4f}, Recall={metrics.box.mr:.4f}")
        
    except Exception as e:
        print(f"Error evaluating {model_name}: {e}")

print("\n=== FINAL RESULTS ===")
for m, res in results_summary.items():
    print(f"{m}:")
    print(f"  mAP50={res['map50']:.4f}, mAP50-95={res['map50-95']:.4f}")
    print(f"  Precision={res['precision']:.4f}, Recall={res['recall']:.4f}")

# Save results to file
import json
from datetime import datetime

# Create results directory if it doesn't exist
results_dir = Path("last-test/test_results_last")
results_dir.mkdir(parents=True, exist_ok=True)

# Save as JSON
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
json_file = results_dir / f"test_results_{timestamp}.json"
with open(json_file, 'w') as f:
    json.dump(results_summary, f, indent=4)
print(f"\nResults saved to: {json_file}")

# Save as formatted text file
txt_file = results_dir / f"test_results_{timestamp}.txt"
with open(txt_file, 'w') as f:
    f.write("=== MODEL EVALUATION RESULTS ===\n")
    f.write(f"Test Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
    
    for m, res in results_summary.items():
        f.write(f"Model: {m}\n")
        f.write(f"  mAP50:     {res['map50']:.4f}\n")
        f.write(f"  mAP50-95:  {res['map50-95']:.4f}\n")
        f.write(f"  Precision: {res['precision']:.4f}\n")
        f.write(f"  Recall:    {res['recall']:.4f}\n")
        f.write("\n")
print(f"Results saved to: {txt_file}")
# Out:
# [final_test] Total Test Images: 199
#
# Evaluating YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_5pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/jovyan/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 84.7KB/s 8.9s 8.9s<0.3ss
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 24.3±6.5 MB/s, size: 62.2 KB)
# val: Scanning /home/jovyan/last-test/labels... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 403.2it/s 0.5s0.1s
# val: New cache created: /home/jovyan/last-test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.3it/s 3.1s0.2s
#                    all        199       2418      0.907      0.883      0.938      0.724
# Speed: 1.3ms preprocess, 10.6ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_
# Result for YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_5pct.pt:
#   mAP50=0.9378, mAP50-95=0.7240
#   Precision=0.9069, Recall=0.8825
#
# Evaluating YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_10pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3221.9±445.0 MB/s, size: 60.0 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 59.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.3it/s 3.0s0.2s
#                    all        199       2418      0.915      0.878      0.943      0.682
# Speed: 1.7ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_2
# Result for YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_10pct.pt:
#   mAP50=0.9427, mAP50-95=0.6815
#   Precision=0.9150, Recall=0.8784
#
# Evaluating YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_20pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3152.6±784.9 MB/s, size: 60.5 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 75.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s0.2s
#                    all        199       2418      0.905      0.828      0.916      0.667
# Speed: 1.7ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_3
# Result for YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_20pct.pt:
#   mAP50=0.9156, mAP50-95=0.6665
#   Precision=0.9051, Recall=0.8280
#
# Evaluating YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_30pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3174.4±1326.8 MB/s, size: 59.8 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 64.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s0.2s
#                    all        199       2418       0.92       0.89      0.941      0.742
# Speed: 1.7ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_4
# Result for YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_30pct.pt:
#   mAP50=0.9406, mAP50-95=0.7424
#   Precision=0.9200, Recall=0.8896
#
# Evaluating YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_40pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2663.7±899.3 MB/s, size: 62.1 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 104.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s0.2s
#                    all        199       2418      0.921      0.892      0.946      0.734
# Speed: 1.7ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_5
# Result for YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_40pct.pt:
#   mAP50=0.9459, mAP50-95=0.7344
#   Precision=0.9214, Recall=0.8916
#
# Evaluating YOLO_OBB_FineTuning_Results/yolo_obb_ft_5pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3431.7±396.0 MB/s, size: 65.3 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 83.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.0it/s 3.3s0.2s
#                    all        199       2418      0.882      0.805      0.906      0.551
# Speed: 1.8ms preprocess, 10.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_6
# Result for YOLO_OBB_FineTuning_Results/yolo_obb_ft_5pct.pt:
#   mAP50=0.9063, mAP50-95=0.5509
#   Precision=0.8822, Recall=0.8048
#
# Evaluating YOLO_OBB_FineTuning_Results/yolo_obb_ft_10pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2270.5±1832.4 MB/s, size: 61.1 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 104.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.1it/s 3.2s0.2s
#                    all        199       2418      0.866      0.756      0.859       0.44
# Speed: 1.4ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_7
# Result for YOLO_OBB_FineTuning_Results/yolo_obb_ft_10pct.pt:
#   mAP50=0.8586, mAP50-95=0.4401
#   Precision=0.8660, Recall=0.7560
#
# Evaluating YOLO_OBB_FineTuning_Results/yolo_obb_ft_20pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3122.4±290.1 MB/s, size: 65.9 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 119.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.3it/s 3.0s0.2s
#                    all        199       2418      0.911      0.787      0.899      0.595
# Speed: 1.4ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_8
# Result for YOLO_OBB_FineTuning_Results/yolo_obb_ft_20pct.pt:
#   mAP50=0.8989, mAP50-95=0.5949
#   Precision=0.9108, Recall=0.7874
#
# Evaluating YOLO_OBB_FineTuning_Results/yolo_obb_ft_30pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3168.3±1127.7 MB/s, size: 57.5 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 104.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s0.2s
#                    all        199       2418      0.843      0.808      0.876      0.539
# Speed: 1.7ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_9
# Result for YOLO_OBB_FineTuning_Results/yolo_obb_ft_30pct.pt:
#   mAP50=0.8764, mAP50-95=0.5393
#   Precision=0.8433, Recall=0.8081
#
# Evaluating YOLO_OBB_FineTuning_Results/yolo_obb_ft_40pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3228.6±611.2 MB/s, size: 62.1 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 119.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.1it/s 3.2s0.2s
#                    all        199       2418      0.874      0.822      0.907      0.598
# Speed: 2.3ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_10
# Result for YOLO_OBB_FineTuning_Results/yolo_obb_ft_40pct.pt:
#   mAP50=0.9073, mAP50-95=0.5984
#   Precision=0.8738, Recall=0.8219
#
# Evaluating YOLO_OBB_FineTuning_Results/yolo_obb_ft_50pct.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3329.4±566.8 MB/s, size: 58.4 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 83.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s0.2s
#                    all        199       2418      0.854      0.839      0.907      0.636
# Speed: 1.9ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_11
# Result for YOLO_OBB_FineTuning_Results/yolo_obb_ft_50pct.pt:
#   mAP50=0.9071, mAP50-95=0.6363
#   Precision=0.8540, Recall=0.8387
#
# Evaluating YOLO_OBB_FineTuning_Results/yolo_obb_scratch_alpha_baseline_40.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3171.9±748.4 MB/s, size: 60.4 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 92.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s0.2s
#                    all        199       2418       0.89      0.846      0.935      0.695
# Speed: 2.0ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_12
# Result for YOLO_OBB_FineTuning_Results/yolo_obb_scratch_alpha_baseline_40.pt:
#   mAP50=0.9350, mAP50-95=0.6955
#   Precision=0.8897, Recall=0.8457
#
# Evaluating YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_Real_Data_only.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2936.3±1022.5 MB/s, size: 61.1 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 92.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.3it/s 3.0s0.2s
#                    all        199       2418      0.944      0.907       0.95      0.808
# Speed: 1.4ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_13
# Result for YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_Real_Data_only.pt:
#   mAP50=0.9497, mAP50-95=0.8081
#   Precision=0.9443, Recall=0.9065
#
# Evaluating YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_E1_Synthesized_only.pt...
# Ultralytics 8.4.12 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2998.6±1077.6 MB/s, size: 65.4 KB)
# val: Scanning /home/jovyan/last-test/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 104.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s0.2s
#                    all        199       2418      0.453      0.483       0.42      0.221
# Speed: 1.7ms preprocess, 10.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/test_14
# Result for YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_E1_Synthesized_only.pt:
#   mAP50=0.4199, mAP50-95=0.2206
#   Precision=0.4530, Recall=0.4835
#
# === FINAL RESULTS ===
# YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_5pct.pt:
#   mAP50=0.9378, mAP50-95=0.7240
#   Precision=0.9069, Recall=0.8825
# YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_10pct.pt:
#   mAP50=0.9427, mAP50-95=0.6815
#   Precision=0.9150, Recall=0.8784
# YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_20pct.pt:
#   mAP50=0.9156, mAP50-95=0.6665
#   Precision=0.9051, Recall=0.8280
# YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_30pct.pt:
#   mAP50=0.9406, mAP50-95=0.7424
#   Precision=0.9200, Recall=0.8896
# YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_40pct.pt:
#   mAP50=0.9459, mAP50-95=0.7344
#   Precision=0.9214, Recall=0.8916
# YOLO_OBB_FineTuning_Results/yolo_obb_ft_5pct.pt:
#   mAP50=0.9063, mAP50-95=0.5509
#   Precision=0.8822, Recall=0.8048
# YOLO_OBB_FineTuning_Results/yolo_obb_ft_10pct.pt:
#   mAP50=0.8586, mAP50-95=0.4401
#   Precision=0.8660, Recall=0.7560
# YOLO_OBB_FineTuning_Results/yolo_obb_ft_20pct.pt:
#   mAP50=0.8989, mAP50-95=0.5949
#   Precision=0.9108, Recall=0.7874
# YOLO_OBB_FineTuning_Results/yolo_obb_ft_30pct.pt:
#   mAP50=0.8764, mAP50-95=0.5393
#   Precision=0.8433, Recall=0.8081
# YOLO_OBB_FineTuning_Results/yolo_obb_ft_40pct.pt:
#   mAP50=0.9073, mAP50-95=0.5984
#   Precision=0.8738, Recall=0.8219
# YOLO_OBB_FineTuning_Results/yolo_obb_ft_50pct.pt:
#   mAP50=0.9071, mAP50-95=0.6363
#   Precision=0.8540, Recall=0.8387
# YOLO_OBB_FineTuning_Results/yolo_obb_scratch_alpha_baseline_40.pt:
#   mAP50=0.9350, mAP50-95=0.6955
#   Precision=0.8897, Recall=0.8457
# YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_Real_Data_only.pt:
#   mAP50=0.9497, mAP50-95=0.8081
#   Precision=0.9443, Recall=0.9065
# YOLO_OBB_Mixed_Training_Results/YOLO26l_OBB_E1_Synthesized_only.pt:
#   mAP50=0.4199, mAP50-95=0.2206
#   Precision=0.4530, Recall=0.4835
#
# Results saved to: last-test/test_results_last/test_results_20260208_125913.json
# Results saved to: last-test/test_results_last/test_results_20260208_125913.txt
