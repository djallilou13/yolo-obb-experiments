# %% [markdown]
# # YOLO-OBB Mixed Data Training (From Scratch)
#
# This notebook trains YOLO-OBB models **from scratch** on varying mixtures of Synthetic and Real-world data.
#
# **Experiments:**
# 1.  **Mixed Data Training**: Train on 100% Synthetic Data + [5%, 10%, 20%, 30%, 40%] of Real Data.
# 2.  **Real Data Baselines**: Train on ONLY [5%, 10%, 20%, 30%, 40%] of Real Data.
#
# **Goal**: Evaluate if adding synthetic data improves performance compared to using only limited real data.

# %% [markdown]
# ## 1. Environment Setup

# %%
# 1. Setup & Imports
import os
import random
import shutil
import numpy as np
from pathlib import Path
from tqdm import tqdm
import yaml
from ultralytics import YOLO
import wandb

# %% [markdown]
# ## 2. Configuration

# %%
# 2. Configuration

# --- DATASET PATHS ---
# Use absolute paths or reliable relative paths based on your environment
REAL_DATASET_PATH = Path("Real_Data/train(80_ REAL DATA)")
SYNTHETIC_DATASET_PATH = Path("Synthetized_Data")
TEST_DATASET_PATH = Path("Real_Data/test(20_ REAL DATA)")
DRIVE_UPLOAD_FOLDER = Path("YOLO_OBB_Mixed_Training_Results")

# Ensure output folder exists
DRIVE_UPLOAD_FOLDER.mkdir(parents=True, exist_ok=True)

# --- MODEL CONFIG ---
BASE_MODEL = "yolo26l-obb.pt"  # Training from scratch using this architecture
WANDB_PROJECT = "YOUR_WANDB_PROJECT"
img_exts = [".jpg", ".jpeg", ".png"]

# --- TRAINING PARAMETERS (FROM SCRATCH) ---
# High Learning Rate, No Freeze, longer epochs if needed (standard is 100)
TRAIN_CONFIG = {
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "workers": 8,
    "optimizer": "AdamW",
    "lr0": 0.001,       # High initial LR for scratch training
    "lrf": 0.01,        # Final LR fraction
    "momentum": 0.937,
    "weight_decay": 0.0005,
    "patience": 25,     # Early stopping
    "save_period": 10,
    "val": True,
    "device": 0,
    "exist_ok": True,
    # Augmentations (Standard YOLO settings or custom)
    "hsv_h": 0.015, "hsv_s": 0.7, "hsv_v": 0.4,
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
    "mixup": 0.0,
}

RANDOM_SEED = 42
random.seed(RANDOM_SEED)

print("Configuration loaded.")
# Out:
# Configuration loaded.

# %% [markdown]
# ## 3. Data Processing & Training Functions

# %%
# --- DATASET SUBFOLDERS ---
SYNTHETIC_SUBFOLDERS = [
    "Capture_as_our_dataset",
    "Capture_scene_8",
    "Capture_zone_with_human_occ2",
    "scene_10"
]

def get_image_files(directory, extensions=img_exts):
    files = []
    if not directory.exists():
        return []
    for ext in extensions:
        files.extend(directory.rglob(f"*{ext}"))
    return sorted(list(set(files)))

def get_all_synthetic_images(base_path, subfolders):
    all_files = []
    for sub in subfolders:
        # Structure: base_path / sub / "images"
        target_dir = base_path / sub / "images"
        if target_dir.exists():
            print(f"Scanning {target_dir}...")
            all_files.extend(get_image_files(target_dir))
        else:
            print(f"Warning: {target_dir} not found!")
    return sorted(list(set(all_files)))

def create_mixed_dataset_yaml(synthetic_path, real_path, real_percentage, run_name):
    """
    Creates a YAML for 100% Synthetic + X% Real data.
    """
    print(f"\n--- Preparing Mixed Dataset for {run_name} ---")
    
    # 1. Get All Synthetic Images
    # UPDATED: Use the new helper to gather from subfolders
    synth_images = get_all_synthetic_images(synthetic_path, SYNTHETIC_SUBFOLDERS)
    print(f"Found {len(synth_images)} Synthetic images.")
    
    # 2. Get Real Images and Subset them
    real_images = get_image_files(real_path / "images")
    random.shuffle(real_images)
    
    subset_size = int(len(real_images) * real_percentage)
    real_subset = real_images[:subset_size]
    print(f"Found {len(real_images)} Real images. Using {real_percentage*100}% -> {len(real_subset)} images.")
    
    # 3. Combine
    mixed_train_images = synth_images + real_subset
    print(f"Total Mixed Training Images: {len(mixed_train_images)}")
    
    # 4. Write train.txt
    train_txt_path = Path(f"{run_name}_train.txt")
    with open(train_txt_path, 'w') as f:
        f.write('\n'.join([str(p.resolve()) for p in mixed_train_images]))
        
    # 5. Create YAML
    val_path = TEST_DATASET_PATH
    
    yaml_content = f"""
path: {Path.cwd()}
train: {train_txt_path.resolve()}
val: {val_path.resolve()}
test: {val_path.resolve()}

nc: 1
names: ['object']
"""
    yaml_path = Path(f"{run_name}_dataset.yaml")
    with open(yaml_path, 'w') as f:
        f.write(yaml_content)
        
    return yaml_path

def create_real_only_yaml(real_path, percentage, run_name):
    """
    Creates a YAML for ONLY X% Real data.
    """
    print(f"\n--- Preparing Real-Only Dataset for {run_name} ---")
    
    # 1. Get Real Images and Subset them
    real_images = get_image_files(real_path / "images")
    random.shuffle(real_images)
    
    subset_size = int(len(real_images) * percentage)
    real_subset = real_images[:subset_size]
    print(f"Found {len(real_images)} Real images. Using {percentage*100}% -> {len(real_subset)} images.")
    
    # 2. Write train.txt
    train_txt_path = Path(f"{run_name}_train.txt")
    with open(train_txt_path, 'w') as f:
        f.write('\n'.join([str(p.resolve()) for p in real_subset]))
        
    # 3. Create YAML
    val_path = TEST_DATASET_PATH
    
    yaml_content = f"""
path: {Path.cwd()}
train: {train_txt_path.resolve()}
val: {val_path.resolve()}
test: {val_path.resolve()}

nc: 1
names: ['object']
"""
    yaml_path = Path(f"{run_name}_dataset.yaml")
    with open(yaml_path, 'w') as f:
        f.write(yaml_content)
        
    return yaml_path

# --- TRAIN EXECUTION WRAPPERS ---

def run_mixed_experiment(pct):
    pct_str = f"{int(pct*100)}pct"
    run_name = f"yolo26l_mixed_{pct_str}"
    print(f"\n>>> STARTING MIXED EXPERIMENT: {run_name} <<<")
    
    # Data
    dataset_yaml = create_mixed_dataset_yaml(SYNTHETIC_DATASET_PATH, REAL_DATASET_PATH, pct, run_name)
    
    # Model
    try: model = YOLO(BASE_MODEL)
    except: model = YOLO("yolo11l-obb.pt")
    
    # Train
    model.train(data=str(dataset_yaml), project=WANDB_PROJECT, name=run_name, **TRAIN_CONFIG)
    
    # Save
    best = Path(model.trainer.save_dir) / "weights" / "best.pt"
    target = DRIVE_UPLOAD_FOLDER / f"{run_name}.pt"
    if best.exists():
        shutil.copy(best, target)
        print(f"Saved to {target}")

def run_real_only_experiment(pct):
    pct_str = f"{int(pct*100)}pct"
    run_name = f"yolo26l_real_only_{pct_str}"
    print(f"\n>>> STARTING REAL-ONLY EXPERIMENT: {run_name} <<<")
    
    # Data
    dataset_yaml = create_real_only_yaml(REAL_DATASET_PATH, pct, run_name)
    
    # Model
    try: model = YOLO(BASE_MODEL)
    except: model = YOLO("yolo11l-obb.pt")
    
    # Train
    model.train(data=str(dataset_yaml), project=WANDB_PROJECT, name=run_name, **TRAIN_CONFIG)
    
    # Save
    best = Path(model.trainer.save_dir) / "weights" / "best.pt"
    target = DRIVE_UPLOAD_FOLDER / f"{run_name}.pt"
    if best.exists():
        shutil.copy(best, target)
        print(f"Saved to {target}")

# %% [markdown]
# ## 4. Mixed Training Experiments
# Training on 100% Synthetic + X% Real Data

# %% [markdown]
# ### 5% Data Experiment

# %%
percentage = 0.05
run_mixed_experiment(percentage)

# %% [markdown]
# ### 10% Data Experiment

# %%
percentage = 0.10
run_mixed_experiment(percentage)
# Out:
# >>> STARTING MIXED EXPERIMENT: yolo26l_mixed_10pct <<<
#
# --- Preparing Mixed Dataset for yolo26l_mixed_10pct ---
# Scanning Synthetized_Data/Capture_as_our_dataset/images...
# Scanning Synthetized_Data/Capture_scene_8/images...
# Scanning Synthetized_Data/Capture_zone_with_human_occ2/images...
# Scanning Synthetized_Data/scene_10/images...
# Found 817 Synthetic images.
# Found 1044 Real images. Using 10.0% -> 104 images.
# Total Mixed Training Images: 921
# New https://pypi.org/project/ultralytics/8.4.10 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.9 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo26l_mixed_10pct_dataset.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26l-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26l_mixed_10pct, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=paper_experiment_mixed, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_10pct, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Tracking run with wandb version 0.24.1
# Run data is saved locally in <code>/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_10pct/wandb/run-20260202_190143-yolo26l_mixed_10pct_20260202_190142</code>
# Syncing run <strong><a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_10pct_20260202_190142' target="_blank">yolo26l_mixed_10pct</a></strong> to <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed</a>
#  View run at <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_10pct_20260202_190142' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_10pct_20260202_190142</a>
# Overriding model.yaml nc=15 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   4497828  ultralytics.nn.modules.head.OBB26            [1, 1, 1, True, [256, 512, 512]]
# YOLO26l-obb summary: 423 layers, 27,875,556 parameters, 27,875,556 gradients, 100.5 GFLOPs
#
# Transferred 1164/1176 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 
0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      98/100      11.2G     0.3889     0.1822     0.1101   0.001103        135        640: 100% ━━━━━━━━━━━━ 57/57 2.4it/s 24.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.865      0.831      0.892      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      99/100      11.1G     0.3941     0.1781      0.114   0.001037        143        640: 100% ━━━━━━━━━━━━ 57/57 2.4it/s 24.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004       0.88      0.816      0.893      0.702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#     100/100      11.3G     0.3852     0.1762     0.1127   0.001006        126        640: 100% ━━━━━━━━━━━━ 57/57 2.4it/s 24.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.878      0.822      0.893      0.702
#
# 100 epochs completed in 0.789 hours.
# Optimizer stripped from /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_10pct/weights/last.pt, 56.4MB
# Optimizer stripped from /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_10pct/weights/best.pt, 56.4MB
#
# Validating /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_10pct/weights/best.pt...
# Ultralytics 8.4.9 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.2it/s 2.9s0.2s
#                    all        225       2004      0.878      0.821      0.893      0.702
# Speed: 0.1ms preprocess, 8.9ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_10pct
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▃████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▁</td></tr><tr><td>lr/pg1</td><td>▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>lr/pg2</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▂▅▄▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇██▇█████████████████</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▃▄▅▅▆▆▆▆▆▇▇▆▇▇▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>metrics/precision(B)</td><td>▁▂▃▅▅▆▅▇▇▇█▇▇▇▇▇▇▇█▇▇▇█▇▇▇▇▇█▇██████████</td></tr><tr><td>metrics/recall(B)</td><td>▁▂▂▄▄▅▅▆▆▆▆▆▇▇▆▆▇▆▆▇▇▇█▇▇▇▇██▇██████████</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>2e-05</td></tr><tr><td>lr/pg1</td><td>2e-05</td></tr><tr><td>lr/pg2</td><td>2e-05</td></tr><tr><td>metrics/mAP50(B)</td><td>0.89346</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.70215</td></tr><tr><td>metrics/precision(B)</td><td>0.87792</td></tr><tr><td>metrics/recall(B)</td><td>0.8218</td></tr><tr><td>model/GFLOPs</td><td>100.51</td></tr><tr><td>model/parameters</td><td>27875556</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>9.709</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">yolo26l_mixed_10pct</strong> at: <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_10pct_20260202_190142' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_10pct_20260202_190142</a><br> View project at: <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed</a><br>Synced 5 W&B file(s), 23 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./runs/obb/paper_experiment_mixed/yolo26l_mixed_10pct/wandb/run-20260202_190143-yolo26l_mixed_10pct_20260202_190142/logs</code>
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Saved to YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_10pct.pt

# %% [markdown]
# ### 20% Data Experiment

# %%
percentage = 0.20
run_mixed_experiment(percentage)
# Out:
# >>> STARTING MIXED EXPERIMENT: yolo26l_mixed_20pct <<<
#
# --- Preparing Mixed Dataset for yolo26l_mixed_20pct ---
# Scanning Synthetized_Data/Capture_as_our_dataset/images...
# Scanning Synthetized_Data/Capture_scene_8/images...
# Scanning Synthetized_Data/Capture_zone_with_human_occ2/images...
# Scanning Synthetized_Data/scene_10/images...
# Found 817 Synthetic images.
# Found 1044 Real images. Using 20.0% -> 208 images.
# Total Mixed Training Images: 1025
# New https://pypi.org/project/ultralytics/8.4.10 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.9 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo26l_mixed_20pct_dataset.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26l-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26l_mixed_20pct, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=paper_experiment_mixed, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_20pct, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Tracking run with wandb version 0.24.1
# Run data is saved locally in <code>/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_20pct/wandb/run-20260202_194936-yolo26l_mixed_20pct_20260202_194933</code>
# Syncing run <strong><a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_20pct_20260202_194933' target="_blank">yolo26l_mixed_20pct</a></strong> to <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed</a>
#  View run at <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_20pct_20260202_194933' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_20pct_20260202_194933</a>
# Overriding model.yaml nc=15 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   4497828  ultralytics.nn.modules.head.OBB26            [1, 1, 1, True, [256, 512, 512]]
# YOLO26l-obb summary: 423 layers, 27,875,556 parameters, 27,875,556 gradients, 100.5 GFLOPs
#
# Transferred 1164/1176 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2615.9±708.5 MB/s, size: 48.9 KB)
# train: Scanning /home/jovyan/Real_Data/train(80_ REAL DATA)/labels... 1025 images, 1 backgrounds, 22 corrupt: 100% ━━━━━━━━━━━━ 1025/1025 435.9it/s 2.4s1s
# train: /home/jovyan/Real_Data/train(80_ REAL DATA)/images/IMG_IMG_3729_JPG.rf.daeae62a6dad2839601bad08b01f2bfe.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: /home/jovyan/Real_Data/train(80_ REAL DATA)/images/IMG_IMG_3747_JPG.rf.fb060b046e0e159ea1d6a1119316d04f.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: /home/jovyan/Real_Data/train(80_ REAL DATA)/images/IMG_IMG_
td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>2e-05</td></tr><tr><td>lr/pg1</td><td>2e-05</td></tr><tr><td>lr/pg2</td><td>2e-05</td></tr><tr><td>metrics/mAP50(B)</td><td>0.89473</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.73478</td></tr><tr><td>metrics/precision(B)</td><td>0.87409</td></tr><tr><td>metrics/recall(B)</td><td>0.82685</td></tr><tr><td>model/GFLOPs</td><td>100.51</td></tr><tr><td>model/parameters</td><td>27875556</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>9.675</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">yolo26l_mixed_20pct</strong> at: <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_20pct_20260202_194933' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_20pct_20260202_194933</a><br> View project at: <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed</a><br>Synced 5 W&B file(s), 23 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./runs/obb/paper_experiment_mixed/yolo26l_mixed_20pct/wandb/run-20260202_194936-yolo26l_mixed_20pct_20260202_194933/logs</code>
# Saved to YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_20pct.pt

# %% [markdown]
# ### 30% Data Experiment

# %%
percentage = 0.30
run_mixed_experiment(percentage)
# Out:
# >>> STARTING MIXED EXPERIMENT: yolo26l_mixed_30pct <<<
#
# --- Preparing Mixed Dataset for yolo26l_mixed_30pct ---
# Scanning Synthetized_Data/Capture_as_our_dataset/images...
# Scanning Synthetized_Data/Capture_scene_8/images...
# Scanning Synthetized_Data/Capture_zone_with_human_occ2/images...
# Scanning Synthetized_Data/scene_10/images...
# Found 817 Synthetic images.
# Found 1044 Real images. Using 30.0% -> 313 images.
# Total Mixed Training Images: 1130
# New https://pypi.org/project/ultralytics/8.4.10 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.9 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo26l_mixed_30pct_dataset.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26l-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26l_mixed_30pct, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=paper_experiment_mixed, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_30pct, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Tracking run with wandb version 0.24.1
# Run data is saved locally in <code>/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_30pct/wandb/run-20260202_204126-yolo26l_mixed_30pct_20260202_204126</code>
# Syncing run <strong><a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_30pct_20260202_204126' target="_blank">yolo26l_mixed_30pct</a></strong> to <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed</a>
#  View run at <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_30pct_20260202_204126' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_30pct_20260202_204126</a>
# Overriding model.yaml nc=15 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2
5s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.897      0.842      0.914      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      92/100      11.6G     0.4606     0.2163       0.12   0.001548        121        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.896      0.841      0.915      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      93/100      11.3G     0.4445     0.2103     0.1184   0.001947         91        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.893      0.843      0.915      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      94/100      11.5G     0.4521     0.2098     0.1177   0.001654         57        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.906      0.837      0.915      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      95/100      11.6G     0.4455     0.2142      0.118   0.001706         87        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.893      0.848      0.915      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      96/100      11.6G     0.4309      0.205     0.1189   0.001474         60        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.902       0.84      0.916      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      97/100      11.9G     0.4422     0.2103       0.12     0.0018         85        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.902      0.841      0.915      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      98/100      11.5G     0.4374     0.2062     0.1176   0.001715        108        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.875      0.854      0.915      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#      99/100      11.6G     0.4332     0.2083     0.1189   0.001696         76        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.4it/s 2.8s0.2s
#                    all        225       2004      0.894       0.84      0.915      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#     100/100      11.6G     0.4336      0.207     0.1188   0.001638         65        640: 100% ━━━━━━━━━━━━ 69/69 2.4it/s 29.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.3it/s 2.8s0.2s
#                    all        225       2004      0.894      0.837      0.915      0.767
#
# 100 epochs completed in 0.932 hours.
# Optimizer stripped from /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_30pct/weights/last.pt, 56.4MB
# Optimizer stripped from /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_30pct/weights/best.pt, 56.4MB
#
# Validating /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_30pct/weights/best.pt...
# Ultralytics 8.4.9 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# YOLO26l-obb summary (fused): 200 layers, 25,594,962 parameters, 0 gradients, 89.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 5.0it/s 3.0s0.2s
#                    all        225       2004      0.902      0.841      0.916      0.768
# Speed: 0.1ms preprocess, 8.9ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_30pct
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▃████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▁▁▁</td></tr><tr><td>lr/pg1</td><td>▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▁▁</td></tr><tr><td>lr/pg2</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▃▃▅▅▅▇▇▇▇▇▇▇███▇████▇██████████████████</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▃▄▄▄▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████████</td></tr><tr><td>metrics/precision(B)</td><td>▁▄▄▅▄▆▆▆▇▇▇▇▇▇██▇▇▇██▇█████████▇█▇██████</td></tr><tr><td>metrics/recall(B)</td><td>▁▃▄▄▅▅▅▅▆▅▆▆▆▇▇▆▆▇▆▇▆▆▇▇▇█▇▇▇██▇█▇█▇███▇</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>2e-05</td></tr><tr><td>lr/pg1</td><td>2e-05</td></tr><tr><td>lr/pg2</td><td>2e-05</td></tr><tr><td>metrics/mAP50(B)</td><td>0.91534</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.76719</td></tr><tr><td>metrics/precision(B)</td><td>0.89447</td></tr><tr><td>metrics/recall(B)</td><td>0.83742</td></tr><tr><td>model/GFLOPs</td><td>100.51</td></tr><tr><td>model/parameters</td><td>27875556</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>9.711</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">yolo26l_mixed_30pct</strong> at: <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_30pct_20260202_204126' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_30pct_20260202_204126</a><br> View project at: <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed</a><br>Synced 5 W&B file(s), 23 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./runs/obb/paper_experiment_mixed/yolo26l_mixed_30pct/wandb/run-20260202_204126-yolo26l_mixed_30pct_20260202_204126/logs</code>
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Saved to YOLO_OBB_Mixed_Training_Results/yolo26l_mixed_30pct.pt

# %% [markdown]
# ### 40% Data Experiment

# %%
percentage = 0.40
run_mixed_experiment(percentage)
# Out:
# >>> STARTING MIXED EXPERIMENT: yolo26l_mixed_40pct <<<
#
# --- Preparing Mixed Dataset for yolo26l_mixed_40pct ---
# Scanning Synthetized_Data/Capture_as_our_dataset/images...
# Scanning Synthetized_Data/Capture_scene_8/images...
# Scanning Synthetized_Data/Capture_zone_with_human_occ2/images...
# Scanning Synthetized_Data/scene_10/images...
# Found 817 Synthetic images.
# Found 1044 Real images. Using 40.0% -> 417 images.
# Total Mixed Training Images: 1234
# New https://pypi.org/project/ultralytics/8.4.10 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.9 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 NVL MIG 1g.24gb, 22144MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo26l_mixed_40pct_dataset.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26l-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26l_mixed_40pct, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=paper_experiment_mixed, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_40pct, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Tracking run with wandb version 0.24.1
# Run data is saved locally in <code>/home/jovyan/runs/obb/paper_experiment_mixed/yolo26l_mixed_40pct/wandb/run-20260202_213743-yolo26l_mixed_40pct_20260202_213743</code>
# Syncing run <strong><a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed/runs/yolo26l_mixed_40pct_20260202_213743' target="_blank">yolo26l_mixed_40pct</a></strong> to <a href='https://wandb.ai/abd-eldjalil-taibi-ensia/paper_experiment_mixed' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai